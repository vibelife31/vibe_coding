# %%
# Import the Python SDK
import google.generativeai as genai
# Used to securely store your API key
from google.colab import userdata

genai.configure(api_key='AIzaSyD_pzEUk3KMgDoxxyzG4JM_cRaY6-5GdWI')

# %%
# https://ai.google.dev/gemini-api/docs/rate-limits?hl=ko#free-tier

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash-preview-05-20
# models/gemini-2.5-flash
# models/gemini-2.5-flash-lite-preview-06-17
# models/gemini-2.5-pro-preview-05-06
# models/gemini-2.5-pro-preview-06-05
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-preview-image-generation
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/learnlm-2.0-flash-experimental
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image-preview
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-preview-09-2025
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-robotics-er-1.5-preview
# models/gemini-2.5-computer-use-preview-10-2025

# %%
gemini_model = genai.GenerativeModel('models/gemini-2.0-flash')

# %%
response = gemini_model.generate_content('최근 생성형 AI 트렌드 알려줘')
print(response.text)
# Out:
# 최근 생성형 AI 트렌드는 매우 빠르게 변화하고 있으며, 다양한 분야에서 혁신적인 발전을 보여주고 있습니다. 주요 트렌드를 몇 가지로 요약하면 다음과 같습니다.
#
# **1. 멀티모달 AI의 발전:**
#
# *   **텍스트, 이미지, 오디오, 비디오 등 다양한 형태의 데이터를 이해하고 생성하는 AI 모델이 등장하고 있습니다.** 예를 들어, 텍스트 설명을 기반으로 이미지를 생성하거나, 이미지와 텍스트를 결합하여 새로운 콘텐츠를 만들 수 있습니다.
# *   **예시:**
#     *   **DALL-E 3, Midjourney:** 텍스트 설명을 기반으로 고품질 이미지 생성
#     *   **Google Gemini:** 텍스트, 이미지, 오디오, 비디오를 통합적으로 처리하는 멀티모달 모델
#
# **2. AI 에이전트의 부상:**
#
# *   **특정 작업을 자율적으로 수행하는 AI 에이전트가 개발되고 있습니다.** 사용자의 목표를 이해하고, 필요한 정보를 검색하고, 작업을 계획하고 실행하여 결과를 제공합니다.
# *   **예시:**
#     *   **Auto-GPT:** 사용자 목표를 기반으로 자율적으로 작업을 수행하는 AI 에이전트
#     *   **Microsoft Copilot:** 사용자의 생산성을 향상시키는 AI 기반 비서
#
# **3. 생성형 AI의 윤리적 문제와 책임감 있는 AI 개발:**
#
# *   **생성형 AI의 악용 가능성(가짜 뉴스 생성, 딥페이크 등)에 대한 우려가 커지면서, 윤리적 문제와 책임감 있는 AI 개발에 대한 관심이 높아지고 있습니다.**
# *   **AI 모델의 투명성, 공정성, 책임성을 확보하기 위한 연구와 규제가 강화되고 있습니다.**
# *   **예시:**
#     *   AI 생성 콘텐츠에 대한 워터마크 표시 의무화
#     *   AI 모델 개발 시 윤리적 가이드라인 준수
#
# **4. 특정 분야에 특화된 생성형 AI 모델:**
#
# *   **일반적인 목적의 생성형 AI 모델 외에도, 특정 산업 또는 작업에 특화된 모델이 개발되고 있습니다.**
# *   **예시:**
#     *   **의료 분야:** 환자 진단 및 치료 지원, 신약 개발
#     *   **금융 분야:** 사기 탐지, 위험 관리
#     *   **법률 분야:** 법률 문서 분석, 계약서 작성
#
# **5. 생성형 AI 도구의 접근성 향상:**
#
# *   **생성형 AI 기술이 더욱 사용자 친화적으로 발전하면서, 일반 사용자도 쉽게 사용할 수 있는 다양한 도구와 플랫폼이 등장하고 있습니다.**
# *   **코딩 지식이 없는 사용자도 AI 모델을 활용하여 콘텐츠를 생성하고, 작업을 자동화할 수 있게 되었습니다.**
# *   **예시:**
#     *   Canva, Simplified: AI 기반 디자인 도구
#     *   Jasper, Copy.ai: AI 기반 글쓰기 도구
#
# **6. 오픈 소스 AI 모델의 확산:**
#
# *   **폐쇄적인 대규모 모델 외에도, 오픈 소스 AI 모델이 활발하게 개발되고 공유되면서, AI 기술의 접근성이 높아지고 있습니다.**
# *   **연구자와 개발자는 오픈 소스 모델을 기반으로 새로운 모델을 개발하고, 다양한 애플리케이션을 구축할 수 있습니다.**
# *   **예시:**
#     *   Llama 2 (Meta): 연구 및 상업적 목적으로 사용 가능한 오픈 소스 LLM
#
# **7. 생성형 AI와 메타버스의 결합:**
#
# *   **생성형 AI는 메타버스 환경에서 사용자 경험을 향상시키는 데 활용될 수 있습니다.**
# *   **AI를 사용하여 가상 세계를 생성하고, 아바타를 커스터마이징하고, 사용자 간의 상호 작용을 풍부하게 만들 수 있습니다.**
#
# 이러한 트렌드는 상호 연관되어 있으며, 앞으로 더욱 발전하고 융합될 것으로 예상됩니다. 생성형 AI 기술은 우리의 삶과 업무 방식에 큰 영향을 미칠 것이며, 이에 대한 지속적인 관심과 학습이 필요합니다.
#
# 좀 더 구체적인 정보나 특정 분야에 대한 트렌드를 알고 싶으시면 언제든지 다시 질문해주세요.

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash-preview-05-20
# models/gemini-2.5-flash
# models/gemini-2.5-flash-lite-preview-06-17
# models/gemini-2.5-pro-preview-05-06
# models/gemini-2.5-pro-preview-06-05
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-preview-image-generation
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/learnlm-2.0-flash-experimental
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image-preview
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-preview-09-2025
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-robotics-er-1.5-preview
# models/gemini-2.5-computer-use-preview-10-2025
